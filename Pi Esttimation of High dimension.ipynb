# %%
import random
import math
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi21 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if (x ** 2 + y ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi21.append((4 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi21)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (4 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.153692614770459

# %%
import random
import math
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi23 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if (x ** 2 + y ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi23.append((4 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi23)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (4 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.1325782811459026

# %%
import random
import math
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi25 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if (x ** 2 + y ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi25.append((4 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi25)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (4 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.1323470611755297

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi31 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi31.append((6 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi31)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (6 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.143712574850299

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi33 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi33.append((6 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi33)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (6 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.135909393737508

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi35 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi35.append((6 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi35)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (6 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.129548180727709

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi41 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi41.append(((32 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi41)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((32 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.1565918102104087

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi43 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi43.append(((32 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi43)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((32 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.13838074663662

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi45 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi45.append(((32 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi45)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((32 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.107046588739564

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi51 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi51.append(((60 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi51)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((60 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.0952929301365475

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi53 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi53.append(((60 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi53)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((60 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.1038005114574267

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi55 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi55.append(((60 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi55)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((60 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.113217491718127

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi61 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi61.append((math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)))
plt.plot(pi61)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.1811264276304922

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi63 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi63.append((math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)))
plt.plot(pi63)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.0508756285840883

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi65 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi65.append((math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)))
plt.plot(pi65)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.067551014719423

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi71 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi71.append(math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3))
plt.plot(pi71)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.11342222849943

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi73 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi73.append(math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3))
plt.plot(pi73)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.025760838123598

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi75 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi75.append(math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3))
plt.plot(pi75)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.1035008380249445

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi81 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi81.append(math.pow((7168 * circlePoints) / (circlePoints + outsidePoints) , 1/4))
plt.plot(pi81)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((7168 * circlePoints) / (circlePoints + outsidePoints) , 1/4)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.414451663400014

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi83 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi83.append(math.pow((7168 * circlePoints) / (circlePoints + outsidePoints) , 1/4))
plt.plot(pi83)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((7168 * circlePoints) / (circlePoints + outsidePoints) , 1/4)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.2195854468629026

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi85 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi85.append(math.pow((7168 * circlePoints) / (circlePoints + outsidePoints) , 1/4))
plt.plot(pi85)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((7168 * circlePoints) / (circlePoints + outsidePoints) , 1/4)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.2090132274534544

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi91 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    t = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2 + t**2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi91.append(math.pow((15120 * circlePoints) / (circlePoints + outsidePoints) , 1/4))
plt.plot(pi91)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((15120 * circlePoints) / (circlePoints + outsidePoints) , 1/4)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.314694549434563

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi93 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    t = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2 + t**2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi93.append(math.pow((15120 * circlePoints) / (circlePoints + outsidePoints) , 1/4))
plt.plot(pi93)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((15120 * circlePoints) / (circlePoints + outsidePoints) , 1/4)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.0419180239561174

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi95 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    t = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2 + t**2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi95.append(math.pow((15120 * circlePoints) / (circlePoints + outsidePoints) , 1/4))
plt.plot(pi95)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((15120 * circlePoints) / (circlePoints + outsidePoints) , 1/4)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.085903490094986

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi101 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    t = random.uniform(-1, 1)
    p = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2 + t**2 + p)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi101.append(math.pow((3840 * circlePoints) / (circlePoints + outsidePoints) , 1/5))
plt.plot(pi101)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((3840 * circlePoints) / (circlePoints + outsidePoints) , 1/5)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 2.4051189464836487

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi103 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    t = random.uniform(-1, 1)
    p = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2 + t**2 + p)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi103.append(math.pow((3840 * circlePoints) / (circlePoints + outsidePoints) , 1/5))
plt.plot(pi103)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((3840 * circlePoints) / (circlePoints + outsidePoints) , 1/5)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 2.4282471875603617

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 1
outsidePoints = 1
pi105 = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    f = random.uniform(-1, 1)
    t = random.uniform(-1, 1)
    p = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2 + f** 2 + t**2 + p)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi105.append(math.pow((3840 * circlePoints) / (circlePoints + outsidePoints) , 1/5))
plt.plot(pi105)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((3840 * circlePoints) / (circlePoints + outsidePoints) , 1/5)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 2.410453069920635

# %%
plt.plot(pi105, label='10th dimension')
plt.plot(pi95, label='9th dimension')
plt.plot(pi85, label='8th dimension')
plt.plot(pi75, label='7th dimension')
plt.plot(pi65, label='6th dimension')
plt.plot(pi55, label='5th dimension')
plt.plot(pi45, label='4th dimension')
plt.plot(pi35, label='3th dimension')
plt.plot(pi25, label='2th dimension')
plt.axhline(y=math.pi, color='black', linestyle='--', label='Pi')

plt.xlabel('iterations')
plt.ylabel('value')

plt.title('5000 iterations')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1), borderaxespad=0.)
# Display the plot
plt.show()

# %%
plt.plot(pi103, label='10th dimension')
plt.plot(pi93, label='9th dimension')
plt.plot(pi83, label='8th dimension')
plt.plot(pi73, label='7th dimension')
plt.plot(pi63, label='6th dimension')
plt.plot(pi53, label='5th dimension')
plt.plot(pi43, label='4th dimension')
plt.plot(pi33, label='3th dimension')
plt.plot(pi23, label='2th dimension')
plt.axhline(y=math.pi, color='black', linestyle='--', label='Pi')

plt.xlabel('iterations')
plt.ylabel('value')

plt.title('3000 iterations')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1), borderaxespad=0.)
# Display the plot
plt.show()

# %%
plt.plot(pi101, label='10th dimension')
plt.plot(pi91, label='9th dimension')
plt.plot(pi81, label='8th dimension')
plt.plot(pi71, label='7th dimension')
plt.plot(pi61, label='6th dimension')
plt.plot(pi51, label='5th dimension')
plt.plot(pi41, label='4th dimension')
plt.plot(pi31, label='3th dimension')
plt.plot(pi21, label='2th dimension')
plt.axhline(y=math.pi, color='black', linestyle='--', label='Pi')

plt.xlabel('iterations')
plt.ylabel('value')
plt.title('1000 iterations')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1), borderaxespad=0.)
# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import scipy.special

p = np.linspace(0, 10, 100)
# Define the functions
def function1(p):
    return (math.pi**(0.5*p))/(0.5*p*scipy.special.gamma(0.5*p))

def function2(p):
    return 2**p

# Calculate y values for each function
y1 = np.log(function1(p))
y2 = np.log(function2(p))

# Plot the graphs
plt.plot(p, y1, label='Function 1: HyperSphere Volume')
plt.plot(p, y2, label='Function 2: Hypercube Volume')

# Add labels and legend
plt.xlabel('Dimensions(p) ')
plt.ylabel('log transfomed volume')
plt.legend()

# Display the plot
plt.show()
# Out:
# C:\Users\prithwihsh\AppData\Local\Temp\ipykernel_26528\1953630455.py:10: RuntimeWarning: invalid value encountered in multiply
#   return (math.pi**(0.5*p))/(0.5*p*scipy.special.gamma(0.5*p))

# %%
import numpy as np
import matplotlib.pyplot as plt
# Define the functions
def function1(p):
    return (math.pi**(0.5*p))/(0.5*p*scipy.special.gamma(0.5*p))
# Generate x values
x = np.linspace(0, 10, 100)
# Calculate y values for each function
y1 = function1(p)
# Plot the graphs
plt.plot(p, y1, label='Function of Hypersphere Volume')
# Add labels and legend
plt.xlabel(' Dimesion(p)')
plt.ylabel('Volume')
plt.legend()
# Display the plot
plt.show()
# Out:
# C:\Users\prithwihsh\AppData\Local\Temp\ipykernel_26528\1656812239.py:5: RuntimeWarning: invalid value encountered in multiply
#   return (math.pi**(0.5*p))/(0.5*p*scipy.special.gamma(0.5*p))
