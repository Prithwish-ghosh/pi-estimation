# %%
import random
import math
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if (x ** 2 + y ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((4 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (4 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.156

# %%
import random
import math
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if (x ** 2 + y ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((4 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (4 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.1333333333333333

# %%
import random
import math
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if (x ** 2 + y ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((4 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (4 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.1328

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((6 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (6 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.144

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((6 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (6 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.136

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((6 * circlePoints) / (circlePoints + outsidePoints))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = (6 * circlePoints) / (circlePoints + outsidePoints)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.1296

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(((32 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((32 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.1546790645008564

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(((32 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((32 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.1377274153969035

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(((32 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((32 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.106638054231616

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(((60 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((60 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.0886890422961

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(((60 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((60 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.1016124838541645

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(((60 * circlePoints) / (circlePoints + outsidePoints))**0.5)
plt.plot(pi)
plt.ylabel('Estimated Pi')
plt.axhline(y=math.pi)
plt.xlabel('Attempts')
plt.show()
pi = ((60 * circlePoints) / (circlePoints + outsidePoints))**0.5
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.1119125951735853

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.1705633777958813

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.0469646412373086

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append((math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((384 * circlePoints) / (circlePoints + outsidePoints), 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.0652377295742124

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 1000
# Estimated value of π = 3.0863779681585846

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 3000
# Estimated value of π = 3.016208566044637

# %%
import random
import matplotlib.pyplot as plt
random.seed(123)
circlePoints = 0
outsidePoints = 0
pi = []

runs = int(input('Number of runs to perform: '))
for i in range(runs):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    z = random.uniform(-1, 1)
    q = random.uniform(-1, 1)
    r = random.uniform(-1, 1)
    w = random.uniform(-1, 1)
    e = random.uniform(-1, 1)
    if (x ** 2 + y ** 2 + z ** 2 + q ** 2 + r ** 2 + w ** 2 + e ** 2)  <= 1:
        circlePoints += 1
    else:
        outsidePoints += 1
    pi.append(math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3))
plt.plot(pi)
plt.axhline(y=math.pi)
plt.ylabel('Estimated Pi')
plt.xlabel('Attempts')
plt.show()
pi = math.pow((840 * circlePoints) / (circlePoints + outsidePoints) , 1/3)
print('Estimated value of π =', pi)
# Out:
# Number of runs to perform: 5000
# Estimated value of π = 3.098091089779063
